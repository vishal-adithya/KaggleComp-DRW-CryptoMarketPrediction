# %% [markdown]
# # DRW - Crypto Market Prediction : Preprocessing Notebook

# %% [markdown]
# ### Dependencies

# %%
import re
import os
import json
import pandas as pd
import xgboost as xgb

# %% [markdown]
# ### Preparing the Data

# %%
train_df = pd.read_parquet(os.path.join("Data","train.parquet"))
train_df.head()
# Out:
#                      bid_qty  ask_qty  buy_qty  sell_qty   volume        X1  \
# timestamp
# 2023-03-01 00:00:00   15.283    8.425  176.405    44.984  221.389  0.121263
# 2023-03-01 00:01:00   38.590    2.336  525.846   321.950  847.796  0.302841
# 2023-03-01 00:02:00    0.442   60.250  159.227   136.369  295.596  0.167462
# 2023-03-01 00:03:00    4.865   21.016  335.742   124.963  460.705  0.072944
# 2023-03-01 00:04:00   27.158    3.451   98.411    44.407  142.818  0.173820
#
#                            X2        X3        X4        X5  ...      X882  \
# timestamp                                                    ...
# 2023-03-01 00:00:00 -0.417690  0.005399  0.125948  0.058359  ...  1.925423
# 2023-03-01 00:01:00 -0.049576  0.356667  0.481087  0.237954  ...  1.928569
# 2023-03-01 00:02:00 -0.291212  0.083138  0.206881  0.101727  ...  1.928047
# 2023-03-01 00:03:00 -0.436590 -0.102483  0.017551  0.007149  ...  1.928621
# ...

# %%
test_df = pd.read_parquet(os.path.join("Data","test.parquet"))
test_df.head()
# Out:
#     bid_qty  ask_qty  buy_qty  sell_qty   volume        X1        X2  \
# ID
# 1     0.114   12.121   10.587    10.971   21.558 -0.732818  0.512331
# 2     2.426    2.962  136.241    12.304  148.545 -0.337995 -0.412176
# 3     1.085    2.343   23.390    57.171   80.561  0.111249  0.458221
# 4    14.793    1.117  116.518    13.082  129.600 -0.149399 -0.640638
# 5     0.033   14.178   43.800    49.836   93.636 -0.694662  0.611254
#
#           X3        X4        X5  ...      X882      X883      X884      X885  \
# ID                                ...
# 1  -0.041982 -0.598260 -0.517646  ...  1.014336  1.367567  1.584126  1.584126
# 2  -0.259468 -0.334809 -0.247443  ...  1.748939  1.848177  0.000131  0.000323
# 3   0.466916  0.574081  0.324722  ...  1.704680  1.772028  0.000550  0.003597
# 4  -0.873778 -1.026144 -0.508816  ...  0.930946  1.037839  1.382037  1.382037
# 5   0.067671 -0.531632 -0.581450  ...  1.080267  1.141878  0.000363  0.012718
#
# ...

# %% [markdown]
# ### Feature Compression

# %%
def Preprocessing(df):
    df.drop(columns = ["bid_qty","ask_qty","sell_qty","volume","buy_qty"],inplace = True)
    return df

# %%
processed_train_df = Preprocessing(train_df)
processed_train_df.head()
# Out:
#                            X1        X2        X3        X4        X5  \
# timestamp
# 2023-03-01 00:00:00  0.121263 -0.417690  0.005399  0.125948  0.058359
# 2023-03-01 00:01:00  0.302841 -0.049576  0.356667  0.481087  0.237954
# 2023-03-01 00:02:00  0.167462 -0.291212  0.083138  0.206881  0.101727
# 2023-03-01 00:03:00  0.072944 -0.436590 -0.102483  0.017551  0.007149
# 2023-03-01 00:04:00  0.173820 -0.213489  0.096067  0.215709  0.107133
#
#                            X6        X7        X8        X9       X10  ...  \
# timestamp                                                              ...
# 2023-03-01 00:00:00  0.027359  0.035780  0.068219  1.034825 -0.029575  ...
# 2023-03-01 00:01:00  0.208359  0.217057  0.249624  0.948694 -0.183488  ...
# 2023-03-01 00:02:00  0.072778  0.081564  0.114166  0.896459 -0.261779  ...
# 2023-03-01 00:03:00 -0.021681 -0.012936  0.019634  0.732634 -0.535845  ...
# 2023-03-01 00:04:00  0.078976  0.087818  0.120426  0.763537 -0.430945  ...
#
# ...

# %%
X_train = processed_train_df.drop(columns=["label"]).values
y_train = processed_train_df["label"].values

print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")
# Out:
# X_train: (525887, 890)
# y_train: (525887,)

# %% [markdown]
# ### Model Training
